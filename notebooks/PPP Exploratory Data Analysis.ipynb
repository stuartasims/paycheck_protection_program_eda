# %% [markdown]
# # Exploring Colorado's Paycheck Protection Program Loan Data
#
# The federal government just released some data on the Paycheck Protection Program Loan recipients. For loans above 150,000, the name, type, address, and some details about ownership were released along with binned ranges for loan amounts. Unfortunately, they did not include specific dollar amounts for loans in this range.
#
# For loans up to $150,000 they did release the exact loan amount but not the business name or specific address. Take a look at some of my data exploration below.
#
# One note: Before well all go hunting down businesses abusing the program and making big claims, some businesses in this data have stated they did not receive, or even apply for, loans under this program but are in the dataset .See [this article](http://mail01.tinyletterapp.com/data-is-plural/data-is-plural-2020-07-08-edition/17448558-www.cnbc.com/2020/07/06/ppp-small-business-coroniavirus-loan-database-contains-errors.html?c=edd6cfc9-960d-4b6c-a66f-c72077ac5ae2) for some coverage. Until we know the veracity of these claims, it's probably best not to go on the hunt for recipients  that abused the program. That being said, [it's obvious and increasingly reported that some recipients don't fit the spirit of a "Small Business" by any stretch of the imagination and should raise some questions](https://chicago.cbslocal.com/2020/07/06/kanye-wests-yeezy-got-millions-from-federal-governments-paycheck-protection-program/).
#
#
# **Note that the data in this notebook is exclusive to Loans where the recorded state is Colorado. High-Level takeaways are in blue box callouts.**
#
# Let's see what we can glean from a first draft analysis.

# %%
from IPython.display import IFrame, Image

# %% [markdown]
# ## Loan Size Distribution

# %% [markdown]
# <div class="span5 alert alert-info">
#
# <b><font size="4"> Nearly 90% of loans in Colorado were for less than 150,000 usd.</b>
#
# </div>

# %%
Image("../reports/figures/loan_size_distribution.png", height=500, width=500)

# %% [markdown]
# ## Recipient Business Type Comparison

# %% [markdown]
# <div class="span5 alert alert-info">
#
# <b><font size="4">Limited Liability Companies (LLCs) are getting the largest loans most frequently (5-10 million), followed by Corporations, and Subchapter S Corporations</b>
#
# </div>

# %%
Image("../reports/figures/large_loans_business_types.png", height=500, width=500)

# %% [markdown]
# ## Small Loans Across Business Types

# %% [markdown]
# <div class="span5 alert alert-info">
#
# <b><font size="4"> There are quite a few small loans ( < $5,000) made. These account for ~9% of all loans received in Colorado. </b>
#
# </div>
#
# Here's the breakdown by business type for these small loans:

# %%
Image("../reports/figures/small_loans_by_business_type.png", height=500, width=500)

# %% [markdown]
# ## Loan Sizes Across All Business Types

# %% [markdown]
# <div class="span5 alert alert-info">
#
# <b> <font size="4">Here's a cross-sectional view of loan ranges and business types where  bars represent how often loans of each range were received.</b>
#
# </div>
#
# **This is a lot to take in. Some helpful examples may include:**
#
#     * Corporations received about 39% of all of the loans made in the 350k - 1 million dollar range.
#     * Sole Proprietorships received about 11% of all the loans made in the $1 - $150,000 Range
#     * LLCs received about 36% of all loans made in the highest loan range, 5-10 million dollars

# %%
Image("../reports/figures/loans_by_business_type_percentage.png", height=1200, width=800)

# %% [markdown]
# ## Non-Profit Vs For-Profit Recipients

# %% [markdown]
# <div class="span5 alert alert-info">
#
# <b><font size="4"> There were 25 For-Profit businesses that received a loan for every Non-Profit recipient in Colorado.</b>
#
# </div>

# %%
Image("../reports/figures/for_vs_nonprofit_balance.png", height=500, width=400)

# %% [markdown]
# ## Jobs Protected Among Recipients

# %% [markdown]
# <div class="span5 alert alert-info">
#
# <b> <font size="4">98% of recipients were what I would consider "Small Businesses" and reported < 100 jobs that would have some proportion of job paychecks protected with their loan.</b>
#
# </div>
# It's important to consider that one element the loan forgiveness conditions specify a certain ratio of the dollars be spent on staff salary. Obviously it's financially wise for most businesses to adhere to those conditions. However, not all businesses may use it in that way so we can't assume that happened across the board.

# %%
Image("../reports/figures/jobs_retained_hist.png", height=500, width=600)

# %% [markdown]
# ## Not exactly "Small" businesses

# %% [markdown]
# <div class="span5 alert alert-info">
#
# <b> <font size="4">The other 2% includes 478 businesses. Here are the 68 For-Profit Businesses that reported >100 jobs protected and got 5-10 million usd.</b>
#
# </div>
# <small> * 1888 Industrial Services Llc</small><br>
# <small> * 4 Rivers Equipment Llc</small><br>
# <small> * Advisors Asset Management Inc</small><br>
# <small> * Alcohol Monitoring Systems Inc.</small><br>
# <small> * All Copy Products Inc.</small><br>
# <small> * Alvarado Concepts Llc</small><br>
# <small> * Amazing Care Home Health Servi</small><br>
# <small> * Apogee Engineering Llc</small><br>
# <small> * Appliance Factory Outlet</small><br>
# <small> * Arapahoe Motors Inc.</small><br>
# <small> * Bad DaddyS International Llc</small><br>
# <small> * Bighorn Construction & Reclamation Llc</small><br>
# <small> * Boston Market Corp</small><br>
# <small> * Brigade Energy Services Llc</small><br>
# <small> * Carepoint P.C.</small><br>
# <small> * Davis Graham & Stubbs Llp</small><br>
# <small> * E2 Optics Llc</small><br>
# <small> * Energy Inspection Services Llc</small><br>
# <small> * Fci Constructors</small><br>
# <small> * First Meridian Services Inc.</small><br>
# <small> * Gcses Ii Holdings Lp</small><br>
# <small> * Gerald H. Phipps Inc.</small><br>
# <small> * Golftec Enterprises Llc</small><br>
# <small> * Gores Vitac Holdings</small><br>
# <small> * Graebel Companies Inc.</small><br>
# <small> * Group Voyagers Inc.</small><br>
# <small> * Haselden Construction</small><br>
# <small> * Inspirato Llc</small><br>
# <small> * Intellisource Llc</small><br>
# <small> * Intrepid Potash Inc.</small><br>
# <small> * K2D Inc</small><br>
# <small> * Kona Grill Acquisition Llc</small><br>
# <small> * Lignetic Inc</small><br>
# <small> * Longbow Industries Llc</small><br>
# <small> * Mac Acquisition Of New Jersey Llc</small><br>
# <small> * Madwire Llc</small><br>
# <small> * Mision Yogurt Inc.</small><br>
# <small> * Motion & Flow Control Products Inc.</small><br>
# <small> * Navajo Transitional Energy Company Llc</small><br>
# <small> * New Age Beverages Corporation</small><br>
# <small> * North Park Transportation Company</small><br>
# <small> * Omnitrax Holdings Combined Inc</small><br>
# <small> * Pax8 Inc.</small><br>
# <small> * Pbs Brand Co. Llc</small><br>
# <small> * Peak 8 Properties Llc</small><br>
# <small> * Performance Energy Services Llc</small><br>
# <small> * Perfx Wireline Services Llc</small><br>
# <small> * Primesource Staffing Llc</small><br>
# <small> * Publication Printers Corp.</small><br>
# <small> * Quality Behavioral Outcomes Llc</small><br>
# <small> * Rocky Mountain Cancer Centers Llp</small><br>
# <small> * Rolfson Oil Llc</small><br>
# <small> * Service Systems Associates Inc.</small><br>
# <small> * Sherman & Howard</small><br>
# <small> * Snooze Import Export Llc</small><br>
# <small> * SullivanS Holding Llc</small><br>
# <small> * Tablerock Holdings Llc</small><br>
# <small> * Teamlinx Lllp</small><br>
# <small> * The Laramar Group Llc</small><br>
# <small> * The One Group Llc</small><br>
# <small> * The Premier Group Staffing Llc</small><br>
# <small> * The Western Sugar Cooperative</small><br>
# <small> * Transwest Freightliner Llc</small><br>
# <small> * Trust-Boston Market Corp</small><br>
# <small> * U.S. TransportInc</small><br>
# <small> * Ward Electric Company Inc.</small><br>
# <small> * Wellbridge Club Management Llc</small><br>
# <small> * WendyS Of Colorado Springs Inc.</small><br>

# %% [markdown]
# ## Specific Loan Amounts vs Jobs Retained

# %% [markdown]
# <div class="span5 alert alert-info">
#
# <b> <font size="3">There does not seem to be any relationship between Loan Amounts and Jobs Protected across the board. In fact, it looks more like I wiped glitter left to right on the chart. <br> <br>
# That said, some Business types such as Limited Liability Partnerships, Cooperatives, Professional Associations, Unreported Types, and Nonprofit Childcare Centers seem to show some linearity in the relationship between Loan amounts and Jobs retained. Perhaps the payscales for the roles in these business types are more consistent?
# </div>
#
# **Tip: double click on a business type in the legend to limit the scatterplot to that grouping**

# %%
IFrame(src='../reports/figures/loan_amount_jobs_protected_scatter.html', width=800, height=600)
# Out:
#         <iframe
#             width="800"
#             height="600"
#             src="../reports/figures/loan_amount_jobs_protected_scatter.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## USD per Job Retained across Business Types

# %% [markdown]
# <div class="span5 alert alert-info">
#
# <b> <font size="4">Since loan amounts <150,000 have specific dollar values, we can explore the ratio between loan amounts and jobs protected by business types. However, we can't identify which specific businesses accounted for these dollar / jobs protected ratios. </b>
# <br>
# <br>
# <b> <font size="4">LLC's, Subchapter S, Regular Corporations, Sole Proprietorships, and Independent contractors have much more variable ratios than other business types</b>
# </div>

# %%
IFrame(src='../reports/figures/usd_job_ratio_boxplot.html', width=800, height=600)
# Out:
#         <iframe
#             width="800"
#             height="600"
#             src="../reports/figures/usd_job_ratio_boxplot.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## Interactive Map of Identifiable Colorado Recipients

# %% [markdown]
# <div class="span5 alert alert-info">
#
# <b> <font size="4">Here's a full map of every loan recipient above the $150,000 that could be found using my geocoding approach.
# <br><br>
#
# <font size="3">By Default, only the largest category of loans (5-10 million) are displayed but you can toggle all the bins with layer controls in the upper right corner
#
# </div>
#
# **Tip: Click on a marker to see the business name, when the loan was approved, and the number of jobs protected**

# %%
IFrame(src='../reports/figures/loan_map.html', width=800, height=500)
# Out:
#         <iframe
#             width="800"
#             height="500"
#             src="../reports/figures/loan_map.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
